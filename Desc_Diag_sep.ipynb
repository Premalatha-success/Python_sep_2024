# %% [markdown]
# #### Whether there is any relnship b/w TM Product and Customer Characteristics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("CardioGoodFitness-1.csv")

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 135   TM498   40  Female         16     Partnered      3        3   61398
# 79    TM195   50  Female         16     Partnered      3        3   64809
# 101   TM498   25    Male         14        Single      3        3   45480
# 25    TM195   24    Male         13     Partnered      3        2   42069
# 26    TM195   24  Female         16        Single      4        3   46617
# 168   TM798   30    Male         18     Partnered      5        4  103336
# 147   TM798   24    Male         18     Partnered      4        5   57271
# 175   TM798   40    Male         21        Single      6        5   83416
# 58    TM195   32    Male         14     Partnered      4        3   52302
# 120   TM498   33    Male         13     Partnered      4        4   53439
#
#      Miles
# 135     85
# 79      66
# 101     95
# 25      47
# 26      75
# 168    160
# 147     80
# 175    200
# 58      85
# 120    170

# %%
df.shape
# Out:
# (180, 9)

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
33-24
# Out:
# 9

# %%
24-1.5*9
# Out:
# 10.5

# %%
33+1.5*9
# Out:
# 46.5

# %% [markdown]
# #### Univariate Analysis->Single variable

# %%
sns.countplot(x="Product",data=df)
plt.show()

# %%
sns.countplot(x="Gender",data=df)
plt.show()

# %%
sns.countplot(x="MaritalStatus",data=df)
plt.show()

# %%
sns.countplot(x="Fitness",data=df)
plt.show()

# %% [markdown]
# countplot->Categorical column

# %%
sns.boxplot(x="Age",data=df)
plt.show()

# %%
sns.boxplot(x="Education",data=df)
plt.show()

# %% [markdown]
# Complete boxplot for Usage,fitness,miles and income
# Inference-> There are outliers in all the columns

# %% [markdown]
# Boxplot->Numerical columns only

# %%
df.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# Histogram-> Normally distributed or not

# %% [markdown]
# Univariate analysis-> categorical(countplot),Numerical->box(outliers,hist(shape)

# %% [markdown]
# #### Bivariate Analysis

# %%
sns.countplot(x="Product",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x="Product",hue="MaritalStatus",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.boxplot(x="Product",y="Age",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Education",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Fitness",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Usage",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Miles",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Income",data=df)
plt.show()

# %%
sns.violinplot(x="Product",y="Income",data=df)
plt.show()

# %%
sns.swarmplot(x="Product",y="Income",data=df)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %% [markdown]
# Both categorical->countplot
# one categ,one num->boxplot(outlier),violinplot(distribution),swarmplot(small dataset-clarity)
# Both numerical->pairplot

# %% [markdown]
# #### Multivariate Analysis

# %%
sns.boxplot(x="Product",y="Age",hue="Gender",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Fitness",hue="Gender",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Miles",hue="Gender",data=df)
plt.show()

# %%
sns.boxplot(x="Product",y="Income",hue="Gender",data=df)
plt.show()

# %%
sns.violinplot(x="Product",y="Income",hue="Gender",data=df)
plt.show()

# %%
sns.swarmplot(x="Product",y="Income",hue="Gender",data=df)
plt.show()

# %%
### https://github.com/Premalatha-success/Datasets/blob/main/titanic-training-data.csv
P.S->Prediction of Survival
Passenger id-> Noise(Donot consider)
Survived-> 0 (Not survived),1->Survived
Pclass->Passengerclass
Name ->Noise(Donot consider)
Sex->
Age->
SibSp-> Sibling /Spouse count
Parch->Parent/Child count
Ticket->Ticket Number(Donot consider)
Fare->Amount(Optional)
Cabin->Important->Many missing values->(Donot consider)
Embarked->Port at which the passenger into the ship
